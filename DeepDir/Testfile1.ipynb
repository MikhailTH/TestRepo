# %%
a = 10 # variable changefghjkl

# %%
print(a)
# Out:
# 10

# %%
import time
time.sleep(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-c20d360cf4b6> in <module>
#       1 import time
# ----> 2 time.sleep(10)
#
# KeyboardInterrupt:

# %%
print("hi, stdout")
# Out:
# hi, stdout

# %%
from __future__ import print_function # change 
print('hi, stderr', file=sys.stderr)
# Out:
# hi, stderr

# %%
import time, sys #importations
for i in range(8):
    print(i)
    time.sleep(0.5)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
# Out:
#   File "<ipython-input-17-bec8e2b8e42d>", line 1
#     for (i=0; i<n; i++) {
#           ^
# SyntaxError: invalid syntax

# %%
for i in range(10):
    print(2**i - 1)
# Out:
# 0
# 1
# 3
# 7
# 15
# 31
# 63
# 127
# 255
# 511
