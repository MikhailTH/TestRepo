# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import FileLink # import address ipython

# %%
import sys
sys.path.insert(0,'..')  
import riemann_tools
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-f0696db84a84> in <module>
#       1 import sys
#       2 sys.path.insert(0,'..')
# ----> 3 import riemann_tools
#
# ModuleNotFoundError: No module named 'riemann_tools'

# %%
import Euler_exact_Riemann_solver
FileLink('Euler_exact_Riemann_solver.py')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-c7c8fa674f1b> in <module>
# ----> 1 import Euler_exact_Riemann_solver
#       2 FileLink('Euler_exact_Riemann_solver.py')
#
# ModuleNotFoundError: No module named 'Euler_exact_Riemann_solver'

# %%
gamma = 1.4

in_vars = 'primitive'  #  components of q are (rho,u,p)

q_l = np.array((3.,0.,3.))
q_r = np.array((1.,0.,1.)) # variables

states, speeds, riemann_eval = Euler_exact_Riemann_solver.exact_riemann_solution(q_l ,q_r, gamma, 
                                                                in_vars=in_vars, out_vars='primitive')

# %%
fig = plt.figure(figsize=(8,3))
ax = plt.subplot(1,2,1)
riemann_tools.plot_phase(states, ax=ax, i_h = 0, i_v = 1, label_h='density', label_v='velocity')
ax = plt.subplot(1,2,2)
riemann_tools.plot_phase(states, ax=ax, i_h = 0, i_v = 2, label_h='density', label_v='pressure')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-833888f6c179> in <module>
#       1 fig = plt.figure(figsize=(8,3))
#       2 ax = plt.subplot(1,2,1)
# ----> 3 riemann_tools.plot_phase(states, ax=ax, i_h = 0, i_v = 1, label_h='density', label_v='velocity')
#       4 ax = plt.subplot(1,2,2)
#       5 riemann_tools.plot_phase(states, ax=ax, i_h = 0, i_v = 2, label_h='density', label_v='pressure')
#
# NameError: name 'riemann_tools' is not defined

# %%
riemann_tools.JSAnimate_plot_riemann(states,speeds,riemann_eval)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9bf9adada70e> in <module>
# ----> 1 riemann_tools.JSAnimate_plot_riemann(states,speeds,riemann_eval)
#
# NameError: name 'riemann_tools' is not defined

# %%
rho_left = q_l[0]
rho_right = q_r[0]
num_right = 10
num_left = 1 + (num_right-1) * rho_left/rho_right

riemann_tools.plot_riemann_trajectories(states,speeds,riemann_eval,i_vel=1,
                                       num_left=num_left, num_right=num_right)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-9bf7fd9d2a38> in <module>
#       4 num_left = 1 + (num_right-1) * rho_left/rho_right
#       5
# ----> 6 riemann_tools.plot_riemann_trajectories(states,speeds,riemann_eval,i_vel=1,
#       7                                        num_left=num_left, num_right=num_right)
#
# NameError: name 'riemann_tools' is not defined

# %%
states, speeds, riemann_eval = Euler_exact_Riemann_solver.exact_riemann_solution(q_l ,q_r, gamma, 
                                                                in_vars='primitive', out_vars='conservative')

fig = plt.figure(figsize=(8,3))
ax = plt.subplot(1,2,1)
riemann_tools.plot_phase(states, ax=ax, i_h = 0, i_v = 1, label_h='density', label_v='momentum')
ax = plt.subplot(1,2,2)
riemann_tools.plot_phase(states, ax=ax, i_h = 0, i_v = 2, label_h='density', label_v='energy')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5e18d091a318> in <module>
# ----> 1 states, speeds, riemann_eval = Euler_exact_Riemann_solver.exact_riemann_solution(q_l ,q_r, gamma,
#       2                                                                 in_vars='primitive', out_vars='conservative')
#       3
#       4 fig = plt.figure(figsize=(8,3))
#       5 ax = plt.subplot(1,2,1)
#
# NameError: name 'Euler_exact_Riemann_solver' is not defined

# %%
riemann_tools.JSAnimate_plot_riemann(states,speeds,riemann_eval)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9bf9adada70e> in <module>
# ----> 1 riemann_tools.JSAnimate_plot_riemann(states,speeds,riemann_eval)
#
# NameError: name 'riemann_tools' is not defined
